# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
#from google.colab import files
#uploaded = files.upload()
from sklearn.datasets import load_iris
df=load_iris()

# %%
import pandas as pd
import numpy as np

# %%
type(df)
# Out:
# sklearn.utils.Bunch

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X=df.data
Y=df.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=100)

# %%
X_train.shape
# Out:
# (112, 4)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from tensorflow.keras.utils import to_categorical

# %%
Y_train=to_categorical(Y_train,3)
Y_test=to_categorical(Y_test,3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
model=tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
from tensorflow.keras.layers import Dense

# %%
model.add(Dense(4, activation='relu', input_shape=(4,)))
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(loss='categorical_crossentropy',
#model.compile(loss='binary_crossentropy',
              optimizer='SGD',
              metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=100)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/100
# 112/112 [==============================] - 1s 5ms/sample - loss: 3.8442 - accuracy: 0.5893 - val_loss: 3.0372 - val_accuracy: 0.6316
# Epoch 2/100
# 112/112 [==============================] - 0s 179us/sample - loss: 2.4174 - accuracy: 0.6786 - val_loss: 2.0874 - val_accuracy: 0.6316
# Epoch 3/100
# 112/112 [==============================] - 0s 163us/sample - loss: 1.7729 - accuracy: 0.6518 - val_loss: 1.6685 - val_accuracy: 0.6316
# Epoch 4/100
# 112/112 [==============================] - 0s 131us/sample - loss: 1.4634 - accuracy: 0.6518 - val_loss: 1.3803 - val_accuracy: 0.6316
# Epoch 5/100
# 112/112 [==============================] - 0s 145us/sample - loss: 1.2417 - accuracy: 0.6607 - val_loss: 1.1898 - val_accuracy: 0.6316
# Epoch 6/100
# 112/112 [==============================] - 0s 144us/sample - loss: 1.1098 - accuracy: 0.6607 - val_loss: 1.0864 - val_accuracy: 0.6316
# Epoch 7/100
# 112/112 [==============================] - 0s 147us/sample - loss: 1.0416 - accuracy: 0.6607 - val_loss: 1.0277 - val_accuracy: 0.6316
# Epoch 8/100
# 112/112 [==============================] - 0s 147us/sample - loss: 1.0000 - accuracy: 0.6518 - val_loss: 0.9864 - val_accuracy: 0.6316
# Epoch 9/100
# 112/112 [==============================] - 0s 137us/sample - loss: 0.9710 - accuracy: 0.6696 - val_loss: 0.9522 - val_accuracy: 0.6316
# Epoch 10/100
# 112/112 [==============================] - 0s 133us/sample - loss: 0.9534 - accuracy: 0.6518 - val_loss: 0.9322 - val_accuracy: 0.6316
# Epoch 11/100
# 112/112 [==============================] - 0s 165us/sample - loss: 0.9367 - accuracy: 0.6607 - val_loss: 0.9119 - val_accuracy: 0.6316
# Epoch 12/100
# 112/112 [==============================] - 0s 139us/sample - loss: 0.9233 - accuracy: 0.6518 - val_loss: 0.8942 - val_accuracy: 0.6316
# Epoch 13/100
# 112/112 [==============================] - 0s 150us/sample - loss: 0.9094 - accuracy: 0.6607 - val_loss: 0.8766 - val_accuracy: 0.6316
# Epoch 14/100
# 112/112 [==============================] - 0s 139us/sample - loss: 0.8966 - accuracy: 0.6607 - val_loss: 0.8541 - val_accuracy: 0.6316
# Epoch 15/100
# 112/112 [==============================] - 0s 175us/sample - loss: 0.8806 - accuracy: 0.6607 - val_loss: 0.8343 - val_accuracy: 0.6316
# Epoch 16/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.8623 - accuracy: 0.6696 - val_loss: 0.8152 - val_accuracy: 0.6316
# Epoch 17/100
# 112/112 [==============================] - 0s 202us/sample - loss: 0.8484 - accuracy: 0.6696 - val_loss: 0.8052 - val_accuracy: 0.6579
# Epoch 18/100
# 112/112 [==============================] - 0s 164us/sample - loss: 0.8385 - accuracy: 0.6696 - val_loss: 0.7953 - val_accuracy: 0.6579
# Epoch 19/100
# 112/112 [==============================] - 0s 153us/sample - loss: 0
100
# 112/112 [==============================] - 0s 151us/sample - loss: 0.6504 - accuracy: 0.6964 - val_loss: 0.6167 - val_accuracy: 0.6316
# Epoch 61/100
# 112/112 [==============================] - 0s 138us/sample - loss: 0.6470 - accuracy: 0.6875 - val_loss: 0.6130 - val_accuracy: 0.6316
# Epoch 62/100
# 112/112 [==============================] - 0s 138us/sample - loss: 0.6446 - accuracy: 0.6875 - val_loss: 0.6114 - val_accuracy: 0.6316
# Epoch 63/100
# 112/112 [==============================] - 0s 143us/sample - loss: 0.6416 - accuracy: 0.6875 - val_loss: 0.6088 - val_accuracy: 0.6316
# Epoch 64/100
# 112/112 [==============================] - 0s 141us/sample - loss: 0.6401 - accuracy: 0.6786 - val_loss: 0.6076 - val_accuracy: 0.6316
# Epoch 65/100
# 112/112 [==============================] - 0s 140us/sample - loss: 0.6364 - accuracy: 0.6964 - val_loss: 0.6025 - val_accuracy: 0.6316
# Epoch 66/100
# 112/112 [==============================] - 0s 151us/sample - loss: 0.6330 - accuracy: 0.6875 - val_loss: 0.6040 - val_accuracy: 0.6316
# Epoch 67/100
# 112/112 [==============================] - 0s 122us/sample - loss: 0.6315 - accuracy: 0.6964 - val_loss: 0.5971 - val_accuracy: 0.6579
# Epoch 68/100
# 112/112 [==============================] - 0s 137us/sample - loss: 0.6275 - accuracy: 0.6875 - val_loss: 0.5944 - val_accuracy: 0.6579
# Epoch 69/100
# 112/112 [==============================] - 0s 144us/sample - loss: 0.6258 - accuracy: 0.6964 - val_loss: 0.5930 - val_accuracy: 0.6316
# Epoch 70/100
# 112/112 [==============================] - 0s 145us/sample - loss: 0.6234 - accuracy: 0.6875 - val_loss: 0.5889 - val_accuracy: 0.6579
# Epoch 71/100
# 112/112 [==============================] - 0s 135us/sample - loss: 0.6201 - accuracy: 0.6875 - val_loss: 0.5880 - val_accuracy: 0.6579
# Epoch 72/100
# 112/112 [==============================] - 0s 148us/sample - loss: 0.6169 - accuracy: 0.6875 - val_loss: 0.5841 - val_accuracy: 0.6579
# Epoch 73/100
# 112/112 [==============================] - 0s 137us/sample - loss: 0.6146 - accuracy: 0.6875 - val_loss: 0.5810 - val_accuracy: 0.6579
# Epoch 74/100
# 112/112 [==============================] - 0s 149us/sample - loss: 0.6120 - accuracy: 0.7054 - val_loss: 0.5800 - val_accuracy: 0.6579
# Epoch 75/100
# 112/112 [==============================] - 0s 132us/sample - loss: 0.6094 - accuracy: 0.6964 - val_loss: 0.5774 - val_accuracy: 0.6842
# Epoch 76/100
# 112/112 [==============================] - 0s 144us/sample - loss: 0.6079 - accuracy: 0.7054 - val_loss: 0.5748 - val_accuracy: 0.6842
# Epoch 77/100
# 112/112 [==============================] - 0s 155us/sample - loss: 0.6045 - accuracy: 0.7321 - val_loss: 0.5696 - val_accuracy: 0.7105
# Epoch 78/100
# 112/112 [==============================] - 0s 151us/sample - loss: 0.6016 - accuracy: 0.7321 - val_loss: 0.5696 - val_accuracy: 0.7105
# Epoch 79/100
# 112/112 [==============================] - 0s 120us/sample - loss: 0.6005 - accuracy: 0.7500 - val_loss: 0.5674 - val_accuracy: 0.7368
# Epoch 80/100
# 112/112 [==============================] - 0s 143us/sample - loss: 0.5984 - accuracy: 0.7500 - val_loss: 0.5643 - val_accuracy: 0.7632
# Epoch 81/100
# 112/112 [==============================] - 0s 137us/sample - loss: 0.5962 - accuracy: 0.7857 - val_loss: 0.5619 - val_accuracy: 0.7632
# Epoch 82/100
# 112/112 [==============================] - 0s 118us/sample - loss: 0.5929 - accuracy: 0.7946 - val_loss: 0.5566 - val_accuracy: 0.7368
# Epoch 83/100
# 112/112 [==============================] - 0s 135us/sample - loss: 0.5893 - accuracy: 0.7946 - val_loss: 0.5537 - val_accuracy: 0.7105
# Epoch 84/100
# 112/112 [==============================] - 0s 136us/sample - loss: 0.5873 - accuracy: 0.7589 - val_loss: 0.5527 - val_accuracy: 0.7632
# Epoch 85/100
# 112/112 [==============================] - 0s 147us/sample - loss: 0.5851 - accuracy: 0.7857 - val_loss: 0.5503 - val_accuracy: 0.7632
# Epoch 86/100
# 112/112 [==============================] - 0s 132us/sample - loss: 0.5826 - accuracy: 0.8125 - val_loss: 0.5469 - val_accuracy: 0.7105
# Epoch 87/100
# 112/112 [==============================] - 0s 125us/sample - loss: 0.5823 - accuracy: 0.7768 - val_loss: 0.5460 - val_accuracy: 0.7105
# Epoch 88/100
# 112/112 [==============================] - 0s 170us/sample - loss: 0.5783 - accuracy: 0.7589 - val_loss: 0.5439 - val_accuracy: 0.7368
# Epoch 89/100
# 112/112 [==============================] - 0s 141us/sample - loss: 0.5749 - accuracy: 0.8036 - val_loss: 0.5406 - val_accuracy: 0.7632
# Epoch 90/100
# 112/112 [==============================] - 0s 148us/sample - loss: 0.5727 - accuracy: 0.7946 - val_loss: 0.5381 - val_accuracy: 0.7895
# Epoch 91/100
# 112/112 [==============================] - 0s 150us/sample - loss: 0.5705 - accuracy: 0.8036 - val_loss: 0.5356 - val_accuracy: 0.7895
# Epoch 92/100
# 112/112 [==============================] - 0s 152us/sample - loss: 0.5694 - accuracy: 0.8125 - val_loss: 0.5332 - val_accuracy: 0.7368
# Epoch 93/100
# 112/112 [==============================] - 0s 161us/sample - loss: 0.5674 - accuracy: 0.7857 - val_loss: 0.5307 - val_accuracy: 0.7368
# Epoch 94/100
# 112/112 [==============================] - 0s 141us/sample - loss: 0.5644 - accuracy: 0.8036 - val_loss: 0.5297 - val_accuracy: 0.7895
# Epoch 95/100
# 112/112 [==============================] - 0s 133us/sample - loss: 0.5627 - accuracy: 0.8214 - val_loss: 0.5267 - val_accuracy: 0.7895
# Epoch 96/100
# 112/112 [==============================] - 0s 145us/sample - loss: 0.5599 - accuracy: 0.8125 - val_loss: 0.5248 - val_accuracy: 0.8158
# Epoch 97/100
# 112/112 [==============================] - 0s 135us/sample - loss: 0.5573 - accuracy: 0.8125 - val_loss: 0.5228 - val_accuracy: 0.8421
# Epoch 98/100
# 112/112 [==============================] - 0s 133us/sample - loss: 0.5547 - accuracy: 0.8393 - val_loss: 0.5194 - val_accuracy: 0.8158
# Epoch 99/100
# 112/112 [==============================] - 0s 162us/sample - loss: 0.5520 - accuracy: 0.8393 - val_loss: 0.5163 - val_accuracy: 0.8158
# Epoch 100/100
# 112/112 [==============================] - 0s 161us/sample - loss: 0.5502 - accuracy: 0.8393 - val_loss: 0.5144 - val_accuracy: 0.8947

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
model.predict(X_test[0:1])
# Out:
# array([[0.04311327, 0.35139015, 0.6054966 ]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
Y_test[0:1]
# Out:
# array([[0., 0., 1.]], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0-rc1

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ca2d9e79-0dd9-4e0c-9a86-071e07cc49c5" name="files[]" multiple disabled />
#      <output id="result-ca2d9e79-0dd9-4e0c-9a86-071e07cc49c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %%
import pandas as pd
import numpy as np

df_price=pd.read_csv("prices.csv")

# %%
df_price.head()
#df_price.shape
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
df_price=df_price.drop(['date','symbol'],axis=1)

# %%
df_price.shape
# Out:
# (851264, 5)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
df_price=df_price[0:1000]
df_price.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
X=df_price[["open", "close", "low", "high"]]
y=df_price['volume']
y=y/1000000

# %%
X.dtypes
# Out:
# open     float64
# close    float64
# low      float64
# high     float64
# dtype: object

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X=np.array(X)
Y=np.array(y)
X=X.astype("float32")
Y=Y.astype("float32")

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X=tf.math.l2_normalize(
    X,
    axis=None,
    epsilon=1e-12,
    name=None
)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
w=tf.zeros(shape=(4,1))
b=tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function 
def prediction(features,w,b):
  y_pred=tf.add(tf.matmul(features,w),b)
  return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(y_actual,y_predicted):
  diff=y_actual-y_predicted
  sqr=tf.square(diff)
  avg=tf.reduce_mean(sqr)
  return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(X,y_actual,w,b,learning_rate=0.01):
  with tf.GradientTape() as t:
    t.watch([w,b])
    current_prediction=prediction(X,w,b)
    current_loss=loss(y_actual,current_prediction)

  dw,db=t.gradient(current_loss,[w,b])  

  w=w-learning_rate *dw
  b=b-learning_rate *db

  return w,b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
  W,b=train(X,Y,w,b)
  print('Current Training loss on iteration',i,loss(Y,prediction(X,w,b)).numpy())
# Out:
# Current Training loss on iteration 0 235.09424
# Current Training loss on iteration 1 234.06282
# Current Training loss on iteration 2 233.07217
# Current Training loss on iteration 3 232.12048
# Current Training loss on iteration 4 231.20685
# Current Training loss on iteration 5 230.32932
# Current Training loss on iteration 6 229.48653
# Current Training loss on iteration 7 228.67712
# Current Training loss on iteration 8 227.89975
# Current Training loss on iteration 9 227.15286
# Current Training loss on iteration 10 226.43588
# Current Training loss on iteration 11 225.74736
# Current Training loss on iteration 12 225.08597
# Current Training loss on iteration 13 224.45088
# Current Training loss on iteration 14 223.84048
# Current Training loss on iteration 15 223.25485
# Current Training loss on iteration 16 222.69215
# Current Training loss on iteration 17 222.15169
# Current Training loss on iteration 18 221.63264
# Current Training loss on iteration 19 221.13428
# Current Training loss on iteration 20 220.65576
# Current Training loss on iteration 21 220.19585
# Current Training loss on iteration 22 219.75436
# Current Training loss on iteration 23 219.33017
